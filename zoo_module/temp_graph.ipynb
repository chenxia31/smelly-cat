# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../input/st_pptn_r_hi.xlsx',sheet_name=None)
for k in df.keys():
    print(df[k].columns)
    try:
        plt.figure()
        plt.bar(list(range(len(df[k]['accp']))),df[k]['accp'])
        break
    except:
        pass
# Out:
# Index(['stcd', 'yr', 'mnth', 'prdtp', 'day', 'hour', 'tm', 'accp', 'moditime'], dtype='object')
